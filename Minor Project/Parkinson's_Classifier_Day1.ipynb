# %% [markdown]
# ### Importing Modules

# %%
import pandas as pd
import numpy as np
import os
os.chdir(
    "D:\\Technocolabs Machine Learning Internship\\Minor Project\\Dataset")

df = pd.read_csv("parkinsons.data")
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
from sklearn.metrics import accuracy_score
import xgboost as xgb
from sklearn.model_selection import train_test_split as tts
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Exploring Data

# %%
df.shape
# Out:
# (195, 24)

# %%
df.columns
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
df.describe(include="all")
# Out:
#                   name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  \
# count              195   195.000000    195.000000    195.000000
# unique             195          NaN           NaN           NaN
# top     phon_R01_S22_6          NaN           NaN           NaN
# freq                 1          NaN           NaN           NaN
# mean               NaN   154.228641    197.104918    116.324631
# std                NaN    41.390065     91.491548     43.521413
# min                NaN    88.333000    102.145000     65.476000
# 25%                NaN   117.572000    134.862500     84.291000
# 50%                NaN   148.790000    175.829000    104.315000
# 75%                NaN   182.769000    224.205500    140.018500
# max                NaN   260.105000    592.030000    239.170000
#
#         MDVP:Jitter(%)  MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  \
# count       195.000000        195.000000  195.000000  195.000000  195.000000
# ...

# %%
# Checking for Missing Values
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %% [markdown]
# There is no missing values.
# Now checking for all data types are correct or not?

# %%
df.dtypes
# Out:
# name                 object
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# status                int64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %%
# creating a temp dataframe to properly explore unique elements and other properties.
temp = pd.DataFrame(index=df.columns)
temp["Data Type"] = df.dtypes
temp["Null Count"] = df.isnull().sum()
temp["Unique Count"] = df.nunique()

temp
# Out:
#                  Data Type  Null Count  Unique Count
# name                object           0           195
# MDVP:Fo(Hz)        float64           0           195
# MDVP:Fhi(Hz)       float64           0           195
# MDVP:Flo(Hz)       float64           0           195
# MDVP:Jitter(%)     float64           0           173
# MDVP:Jitter(Abs)   float64           0            19
# MDVP:RAP           float64           0           155
# MDVP:PPQ           float64           0           165
# Jitter:DDP         float64           0           180
# MDVP:Shimmer       float64           0           188
# MDVP:Shimmer(dB)   float64           0           149
# Shimmer:APQ3       float64           0           184
# Shimmer:APQ5       float64           0           189
# MDVP:APQ           float64           0           189
# Shimmer:DDA        float64           0           189
# NHR                float64           0           185
# HNR                float64           0           195
# ...

# %% [markdown]
# Checking for correlation

# %%
df.corr()
# Out:
#                   MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# MDVP:Fo(Hz)          1.000000      0.400985      0.596546       -0.118003
# MDVP:Fhi(Hz)         0.400985      1.000000      0.084951        0.102086
# MDVP:Flo(Hz)         0.596546      0.084951      1.000000       -0.139919
# MDVP:Jitter(%)      -0.118003      0.102086     -0.139919        1.000000
# MDVP:Jitter(Abs)    -0.382027     -0.029198     -0.277815        0.935714
# MDVP:RAP            -0.076194      0.097177     -0.100519        0.990276
# MDVP:PPQ            -0.112165      0.091126     -0.095828        0.974256
# Jitter:DDP          -0.076213      0.097150     -0.100488        0.990276
# MDVP:Shimmer        -0.098374      0.002281     -0.144543        0.769063
# MDVP:Shimmer(dB)    -0.073742      0.043465     -0.119089        0.804289
# Shimmer:APQ3        -0.094717     -0.003743     -0.150747        0.746625
# Shimmer:APQ5        -0.070682     -0.009997     -0.101095        0.725561
# ...

# %% [markdown]
# Inspecting by heatmap

# %%
corrplot = df.corr()
f, ax = plt.subplots(figsize=(9, 8))
sns.heatmap(corrplot, ax=ax, linewidth=0.2)

# %%
feature = corrplot['status'] >= 0.25
feature
# Out:
# MDVP:Fo(Hz)         False
# MDVP:Fhi(Hz)        False
# MDVP:Flo(Hz)        False
# MDVP:Jitter(%)       True
# MDVP:Jitter(Abs)     True
# MDVP:RAP             True
# MDVP:PPQ             True
# Jitter:DDP           True
# MDVP:Shimmer         True
# MDVP:Shimmer(dB)     True
# Shimmer:APQ3         True
# Shimmer:APQ5         True
# MDVP:APQ             True
# Shimmer:DDA          True
# NHR                 False
# HNR                 False
# status               True
# RPDE                 True
# DFA                 False
# spread1              True
# spread2              True
# D2                   True
# PPE                  True
# Name: status, dtype: bool

# %% [markdown]
# Here we set the threshold to be 0.25 and selecting the columns as features for the model.

# %%
notimpfeat = [
    "MDVP:Fo(Hz)", "MDVP:Fhi(Hz)", "MDVP:Flo(Hz)", "NHR", "HNR", "DFA"
]

# %% [markdown]
# Inspecting Target Variable : Status

# %%
df['status'].value_counts()
# Out:
# 1    147
# 0     48
# Name: status, dtype: int64

# %%
df['status'].value_counts().plot(kind="bar", title="Bar plot for status")

# %% [markdown]
# Checking for outliers

# %%
df.boxplot()

# %% [markdown]
# As the first three columns are not important features we can ignore.

# %% [markdown]
# ### Preprocessing Data

# %%
df_featured = df.drop(notimpfeat, axis=1)

# %%
df_featured.shape
# Out:
# (195, 18)

# %% [markdown]
# Now we have 18 features to be processed

# %%
x = df_featured.drop(["status", "name"], axis=1)
y = df_featured["status"]

# %% [markdown]
# Scaling the values

# %%
col = x.columns
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
x = pd.DataFrame(x_scaled, columns=col)
x.head()
# Out:
#    MDVP:Jitter(%)  MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  \
# 0        0.334914          0.749759  0.132963  0.760800    0.131755
# 1        0.715418          1.037674  0.453892  1.276809    0.452684
# 2        0.884991          1.325589  0.720770  1.585687    0.721813
# 3        0.775389          1.325589  0.578885  1.284076    0.577677
# 4        1.368893          1.901418  1.095750  2.047187    1.096793
#
#    MDVP:Shimmer  MDVP:Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  MDVP:APQ  \
# 0      0.745985          0.739536      0.607859      1.119147  0.332985
# 1      1.681731          1.768464      1.547912      2.276504  1.159454
# 2      1.202693          1.027636      1.175643      1.726176  0.699187
# 3      1.340396          1.207698      1.340547      1.848749  0.806859
# 4      1.836448          1.552389      1.899444      2.532491  1.216839
#
#    Shimmer:DDA      RPDE   spread1   spread2        D2       PPE
# ...

# %%
x.shape
# Out:
# (195, 16)

# %%
y.shape
# Out:
# (195,)

# %% [markdown]
# ### Splitting Data

# %% [markdown]
# Making Stratified Distribution so that the target variable is distributed in training and testing set equally.

# %%
train_x, test_x, train_y, test_y = tts(x, y, test_size=0.2,random_state=96, stratify=y)

# %% [markdown]
# ### Model Building

# %%
temp_model = xgb.XGBClassifier()

temp_model.fit(train_x, train_y)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
temp_train_predict = temp_model.predict(train_x)
temp_test_predict = temp_model.predict(test_x)

temp_train_score = accuracy_score(temp_train_predict, train_y)
temp_test_score = accuracy_score(temp_test_predict, test_y)
print("Training Score : ", temp_train_score)
print("Testing Score : ", temp_test_score)
# Out:
# Training Score :  1.0
# Testing Score :  0.8461538461538461

# %% [markdown]
# This model has perfect training accuracy but low testing score. This model provides high variance. The model is unreliable.

# %% [markdown]
# Tuning Parameter

# %%
model = xgb.XGBClassifier(colsample_bytree=0.8,
                          gamma=0,
                          learning_rate=0.001,
                          max_depth=4,
                          min_child_weight=6,
                          n_estimators=1000,
                          alpha=10,
                          reg_lambda=0.001,
                          subsample=0.6,
                          seed=40)

model.fit(train_x, train_y)
# Out:
# XGBClassifier(alpha=10, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.001, max_delta_step=0, max_depth=4,
#               min_child_weight=6, missing=nan, monotone_constraints='()',
#               n_estimators=1000, n_jobs=0, num_parallel_tree=1, random_state=40,
#               reg_alpha=10, reg_lambda=0.001, scale_pos_weight=1, seed=40,
#               subsample=0.6, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
train_predict = model.predict(train_x)
test_predict = model.predict(test_x)

train_score = accuracy_score(train_predict, train_y)
test_score = accuracy_score(test_predict, test_y)
print("Training Score : ", train_score)
print("Testing Score : ", test_score)
# Out:
# Training Score :  0.782051282051282
# Testing Score :  0.7692307692307693

# %% [markdown]
# Now the model is reliable.But we need to tune the parameters and apply k-fold cross validation technique.
